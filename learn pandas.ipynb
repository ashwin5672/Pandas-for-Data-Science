# %% [markdown]
# ## Learn pandas for data analysis

# %% [markdown]
# ### Importing the data

# %%
import pandas as pd

# %%
df=pd.read_csv('new_data.csv')

# %%
df
# Out:
#     first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0      Chickie    Brister    Male                                   86
# 1        Morly     Genery    Male                                   69
# 2      Ardelis  Forrester  Female                                   10
# 3       Lucine      Stutt  Female                                   64
# 4      Melinda     Hadlee  Female                                   34
# ..         ...        ...     ...                                  ...
# 710  Ferdinand  Romanetti    Male                                   60
# 711       Burk    Wortley    Male                                   22
# 712   Melloney      Temby  Female                                   17
# 713     Dickie    Cubbini    Male                                   30
# 714      Sylas    Duffill    Male                                   56
#
#             DOB                     job_title job_industry_category  \
# ...

# %%
df1=pd.read_excel('ORDER SHEET.xlsx')

# %% [markdown]
# ### Viewing data in pandas

# %%
df.head(10)
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
# 5      Druci    Brandli  Female                                   39
# 6   Rutledge      Hallt    Male                                   23
# 7     Nancie       Vian  Female                                   74
# 8       Duff  Karlowicz    Male                                   50
# 9    Barthel     Docket    Male                                   72
#
#           DOB                     job_title job_industry_category  \
# 0  1957-07-12               General Manager         Manufacturing
# 1  1970-03-22           Structural Engineer              Property
# ...

# %%
df.tail()
# Out:
#     first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 710  Ferdinand  Romanetti    Male                                   60
# 711       Burk    Wortley    Male                                   22
# 712   Melloney      Temby  Female                                   17
# 713     Dickie    Cubbini    Male                                   30
# 714      Sylas    Duffill    Male                                   56
#
#             DOB                     job_title job_industry_category  \
# 710  1959-10-07                     Paralegal    Financial Services
# 711  2001-10-17        Senior Sales Associate                Health
# 712  1954-10-05  Budget/Accounting Analyst IV    Financial Services
# 713  1952-12-17             Financial Advisor    Financial Services
# 714  1955-10-02           Staff Accountant IV              Property
#
#         wealth_segment deceased_indicator owns_car  tenure  \
# 710  Affluent Customer                  N       No       9
# ...

# %%
df.shape
# Out:
# (715, 20)

# %% [markdown]
# ### Data Exploration

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 715 entries, 0 to 714
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           715 non-null    object
#  1   last_name                            715 non-null    object
#  2   gender                               715 non-null    object
#  3   past_3_years_bike_related_purchases  715 non-null    int64
#  4   DOB                                  715 non-null    object
#  5   job_title                            715 non-null    object
#  6   job_industry_category                715 non-null    object
#  7   wealth_segment                       715 non-null    object
#  8   deceased_indicator                   715 non-null    object
#  9   owns_car                             715 non-null    object
#  10  tenure                               715 non-null    int64
# ...

# %%
df.describe()
# Out:
#        past_3_years_bike_related_purchases      tenure     postcode  \
# count                           715.000000  715.000000   715.000000
# mean                             49.806993   11.349650  3033.420979
# std                              27.735227    5.011274   851.685794
# min                               0.000000    1.000000  2000.000000
# 25%                              27.000000    7.000000  2212.500000
# 50%                              51.000000   11.000000  3013.000000
# 75%                              71.500000   15.000000  3855.000000
# max                              99.000000   22.000000  4879.000000
#
#        property_valuation         Rank       Value     num_age
# count          715.000000   715.000000  715.000000  715.000000
# mean             7.386014   507.942657    0.873785   51.667133
# std              2.830274   290.855597    0.296971   17.048160
# min              1.000000     1.000000    0.340000   21.000000
# ...

# %%
df['wealth_segment'].value_counts()
# Out:
# Mass Customer        362
# High Net Worth       180
# Affluent Customer    173
# Name: wealth_segment, dtype: int64

# %% [markdown]
# ### Filtering Data

# %%
# job_industry_category = Manufacturing & wealth_segment=Mass Customer

# %%
df.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#           DOB                   job_title job_industry_category  \
# 0  1957-07-12             General Manager         Manufacturing
# 1  1970-03-22         Structural Engineer              Property
# 2  1974-08-28      Senior Cost Accountant    Financial Services
# 3  1979-01-28  Account Representative III         Manufacturing
# 4  1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  tenure              address  \
# 0      Mass Customer                  N      Yes      14     45 Shopko Center
# ...

# %%
data = df[(df['job_industry_category']=='Manufacturing') & (df['wealth_segment']=='Mass Customer')]

# %%
df[df['job_industry_category']=='Manufacturing']
# Out:
#      first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0       Chickie    Brister    Male                                   86
# 3        Lucine      Stutt  Female                                   64
# 8          Duff  Karlowicz    Male                                   50
# 11      Wheeler    Winward    Male                                   48
# 14     Marcelia  Monkleigh  Female                                   61
# ..          ...        ...     ...                                  ...
# 688  Clarabelle   Broschek  Female                                    6
# 689      Tillie   Bisseker  Female                                   74
# 691      Evered     Gludor    Male                                    3
# 704        Vyky       Pegg  Female                                   64
# 706       Bryan    Jachtym    Male                                   59
#
#             DOB                   job_title job_industry_category  \
# ...

# %% [markdown]
# ### Cleaning the data

# %%
data = df[(df['job_industry_category']=='Manufacturing') & (df['wealth_segment']=='Mass Customer')]

# %%
data.duplicated()
# Out:
# 0      False
# 8      False
# 11     False
# 14     False
# 18     False
#        ...
# 663    False
# 685    False
# 688    False
# 704    False
# 706    False
# Length: 75, dtype: bool

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [first_name, last_name, gender, past_3_years_bike_related_purchases, DOB, job_title, job_industry_category, wealth_segment, deceased_indicator, owns_car, tenure, address, postcode, state, country, property_valuation, Rank, Value, num_age, cat_age]
# Index: []

# %%
data1=data.drop_duplicates()

# %%
data.drop_duplicates(inplace=True)
# Out:
# C:\Users\Ashwin\AppData\Local\Temp\ipykernel_23328\2282015914.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop_duplicates(inplace=True)

# %% [markdown]
# ### to check null values

# %%
data.isnull()
# Out:
#      first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0         False      False   False                                False
# 8         False      False   False                                False
# 11        False      False   False                                False
# 14        False      False   False                                False
# 18        False      False   False                                False
# ..          ...        ...     ...                                  ...
# 663       False      False   False                                False
# 685       False      False   False                                False
# 688       False      False   False                                False
# 704       False      False   False                                False
# 706       False      False   False                                False
#
#        DOB  job_title  job_industry_category  wealth_segment  \
# ...

# %%
data.isnull().sum()
# Out:
# first_name                             0
# last_name                              0
# gender                                 0
# past_3_years_bike_related_purchases    0
# DOB                                    0
# job_title                              0
# job_industry_category                  0
# wealth_segment                         0
# deceased_indicator                     0
# owns_car                               0
# tenure                                 0
# address                                0
# postcode                               0
# state                                  0
# country                                0
# property_valuation                     0
# Rank                                   0
# Value                                  0
# num_age                                0
# cat_age                                0
# dtype: int64

# %% [markdown]
# ### Fill null values

# %%
data['tenure']
# Out:
# 0      14
# 8       5
# 11     10
# 14      4
# 18     13
#        ..
# 663     6
# 685    13
# 688    18
# 704    11
# 706    15
# Name: tenure, Length: 75, dtype: int64

# %%
data['tenure'].fillna(20)
# Out:
# 0      14
# 8       5
# 11     10
# 14      4
# 18     13
#        ..
# 663     6
# 685    13
# 688    18
# 704    11
# 706    15
# Name: tenure, Length: 75, dtype: int64
